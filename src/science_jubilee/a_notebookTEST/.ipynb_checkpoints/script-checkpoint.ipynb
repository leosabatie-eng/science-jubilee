# %% [markdown]
# Choix des paramètres
#
# Avant de commencer l'expérience, utilisés l'interface graphique pour :
# Définir le deck et les outils utilisés
# Imprimer le moule, plaque lasercut, a l'aide du fichier DXF
# Choisir les paramètres de l'expériences
# placer le fichier JSON dans le dossier A REMPLIR

# %%
from science_jubilee.JubileeManager import JubileeManager
from science_jubilee.decks.LoadAll import load_all
from science_jubilee.tools.Detection_erreur import Detection_erreur

# %%
# Connexion à la Jubilee
jm = JubileeManager(address="10.0.9.6", simulated=True)
detect = Detection_erreur
# Out:
# 2026-02-20 15:40:38 - [JubileeController]  - INFO - Initializing JubileeController (simulated=False, address=10.0.9.6)
# 2026-02-20 15:40:38 - [JubileeController]  - WARNING - Disconnecting this application from the network will halt connection to Jubilee.
# 2026-02-20 15:40:38 - [JubileeController]  - INFO - Connecting to Jubilee machine...
# 2026-02-20 15:40:38 - [JubileeController]  - INFO - Successfully connected and initialized Jubilee machine.
# 2026-02-20 15:40:38 - [JubileeManager]     - INFO - JubileeManager initialized (simulated=False, max_tools=4).

# %%
# Homing
jm.controller.home_all()
# Out:
# Is a tool currently mounted? [y/n]  n
# Is the deck clear of any obstacles? [y/n]  y
# 2026-02-20 15:41:47 - [JubileeController]  - INFO - All axes homed successfully.

# %% [markdown]
# Préparation de l'expérience
#
# - Placer le deck d'expérience
# - Placer les outils nécéssaires

# %%
# Descendre le plateau pour positionner le deck
jm.controller.move_to(z=300)
jm.controller.move_to(x=150, y=150)

# %%
# Enregistrer le deck
deck = jm.load_deck("test1")
load_all(jm,"test1")
# Out:
# 2026-02-20 15:42:05 - [Deck]               - INFO - Loading deck configuration from: /home/sworkyx/Documents/Polytech/Projet_indus/science-jubilee/src/science_jubilee/decks/deck_definition/test1.json
# 2026-02-20 15:42:05 - [Deck]               - INFO - Deck 'Experience1' loaded with 1 slots.
# 2026-02-20 15:42:05 - [JubileeManager]     - INFO - Deck 'Experience1' loaded from '/home/sworkyx/Documents/Polytech/Projet_indus/science-jubilee/src/science_jubilee/decks/deck_definition'.
# 2026-02-20 15:42:05 - [Tool]               - INFO - Tool 'Pipette' (index 1) initialized.
# 2026-02-20 15:42:05 - [JubileeManager]     - INFO - Tool 'Pipette' loaded at index 1.

# %%
#affiche les slots
jm.deck.list_slots()
jm.deck.get_all_slot_machine_coordinates()
# Out:
# {'0': (10.12, 10.26)}

# %%
jm.status()
# Out:
# {'deck': 'Experience1',
#  'tools': [{'index': 1, 'name': 'Pipette'}],
#  'active_tool_index': 1,
#  'active_tool_name': 'Pipette',
#  'tool_offsets': {}}

# %% [markdown]
# Début de l'expérience :

# %%
#Saisie de l'outil Inoculateur

dict = jm.get_tool_by_name('Pipette')
jm.controller.pickup_tool_sequence(dict['index'])
jm.set_active_tool(dict['index'])
jm.set_tool_offset(1, (0, -31.5,35))
# Out:
# 2026-02-20 16:09:26 - [JubileeController]  - INFO - Starting pickup_tool sequence for tool 1.
# 2026-02-20 16:09:29 - [JubileeController]  - INFO - pickup_tool_sequence completed for tool 1.
# 2026-02-20 16:09:29 - [JubileeManager]     - INFO - Tool at index 1 set as active tool.
# 2026-02-20 16:09:29 - [JubileeManager]     - INFO - Offset for tool at index 1 set to (0, -31.5, 35).

# %%
for slot_index in jm.deck.list_slots():
    slot = jm.deck.get_slot(slot_index)
    if slot.has_labware and slot.labware is not None:
        labware = slot.labware
        for well_name in labware.wells:
            x, y, z = jm.deck.get_well_machine_coordinates(slot_index, well_name)
            print(f"Slot {slot_index} - Well {well_name}: x={x}, y={y}, z={z}")
            jm.move_active_tool_effector_to(x, y, z=50, s=5000, wait=True)
            detect.capture_octopi_image("avant");
            #action : ex dépot lentille
            #jm.move_active_tool_effector_to(x, y, z=100, s=5000, wait=True)
            """detect.capture_octopi_image();
            detect.detect_diff();
            while(detect.detect_diff() == False):
                #detect.capture_octopi_image();
                #action Inoculateur
                detect.capture_octopi_image();
                """


    jm.controller.move_to(z=100)
# Out:
# 2026-02-20 15:43:33 - [JubileeManager]     - INFO - Moving active tool at index 1 to (x=25.119999999999997, y=25.259999999999998, z=50, u=None) with offset (0.0, 0.0, 0.0) (machine position: 25.119999999999997, 25.259999999999998, 50.0, None).
# Slot 0 - Well A1: x=25.119999999999997, y=25.259999999999998, z=2.5
# Connexion à OctoPi...
# 2026-02-20 15:43:38 - [JubileeManager]     - INFO - Moving active tool at index 1 to (x=44.62, y=25.259999999999998, z=50, u=None) with offset (0.0, 0.0, 0.0) (machine position: 44.62, 25.259999999999998, 50.0, None).
# Image capturée et enregistrée : avant.jpg
# Slot 0 - Well B1: x=44.62, y=25.259999999999998, z=2.5
# 2026-02-20 15:43:39 - [JubileeManager]     - INFO - Moving active tool at index 1 to (x=64.12, y=25.259999999999998, z=50, u=None) with offset (0.0, 0.0, 0.0) (machine position: 64.12, 25.259999999999998, 50.0, None).
# Connexion à OctoPi...
# Image capturée et enregistrée : avant.jpg
# ...
