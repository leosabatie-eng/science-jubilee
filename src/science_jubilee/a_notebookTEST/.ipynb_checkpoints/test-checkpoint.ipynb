# %%
from science_jubilee.JubileeManager import JubileeManager
from science_jubilee.decks.LoadAll import load_all
from science_jubilee.tools.Detection_erreur import Detection_erreur

# %%
# Connexion à la Jubilee
jm = JubileeManager(address="10.0.9.6", simulated=True)
detect = Detection_erreur
# Out:
# 2026-02-27 10:11:21 - [JubileeController]  - INFO - Initializing JubileeController (simulated=False, address=10.0.9.6)
# 2026-02-27 10:11:21 - [JubileeController]  - WARNING - Disconnecting this application from the network will halt connection to Jubilee.
# 2026-02-27 10:11:21 - [JubileeController]  - INFO - Connecting to Jubilee machine...
# 2026-02-27 10:11:22 - [JubileeController]  - INFO - Successfully connected and initialized Jubilee machine.
# 2026-02-27 10:11:22 - [JubileeManager]     - INFO - JubileeManager initialized (simulated=False, max_tools=4).

# %%
# Homing
jm.controller.home_all()
# Out:
# Is a tool currently mounted? [y/n]  n
# Is the deck clear of any obstacles? [y/n]  y
# 2026-02-27 09:50:29 - [JubileeController]  - INFO - All axes homed successfully.

# %%
# Descendre le plateau pour positionner le deck
jm.controller.move_to(z=300)
jm.controller.move_to(x=150, y=150)

# %%
# Enregistrer le deck
deck = jm.load_deck("test1")
load_all(jm,"test1")
# Out:
# 2026-02-27 09:50:50 - [Deck]               - INFO - Loading deck configuration from: /home/sworkyx/Documents/Polytech/Projet_indus/science-jubilee/src/science_jubilee/decks/deck_definition/test1.json
# 2026-02-27 09:50:50 - [Deck]               - INFO - Deck 'Experience1' loaded with 1 slots.
# 2026-02-27 09:50:50 - [JubileeManager]     - INFO - Deck 'Experience1' loaded from '/home/sworkyx/Documents/Polytech/Projet_indus/science-jubilee/src/science_jubilee/decks/deck_definition'.
# 2026-02-27 09:50:50 - [Tool]               - INFO - Tool 'Pipette' (index 1) initialized.
# 2026-02-27 09:50:50 - [JubileeManager]     - INFO - Tool 'Pipette' loaded at index 1.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Enregistrer le deck
#       2 deck = jm.load_deck("test1")
# ----> 3 load_all(jm,"test1")
#
# File ~/Documents/Polytech/Projet_indus/science-jubilee/src/science_jubilee/decks/LoadAll.py:58, in load_all(jm, deck_filename, path)
#      56     tool = Tool(index=index, name=tool_name)
#      57     jm.load_tool(tool, index)
# ---> 58     offset
#      59     jm.set_tool_offset(0, (0, -43.5,0))
#      61 slots_cfg = deck_config.get("slots")
#
# NameError: name 'offset' is not defined

# %%
#affiche les slots
jm.deck.list_slots()
jm.deck.get_all_slot_machine_coordinates()
# Out:
# {'0': (10.12, 10.26)}

# %%
jm.status()
# Out:
# {'deck': 'Experience1',
#  'tools': [{'index': 1, 'name': 'Pipette'}],
#  'active_tool_index': None,
#  'active_tool_name': None,
#  'tool_offsets': {}}

# %%
# jm.controller.move_to(x=150, y=150)
jm.controller.move_to(z=50)

detect.capture_octopi_image("avant");
# Out:
# Connexion à OctoPi...
# Erreur : statut HTTP 503

# %%
detect.capture_octopi_image("apres");
# Out:
# Connexion à OctoPi...
# Image capturée et enregistrée : après.jpg

# %%
detect.detect_diff("test")
# Out:
# Erreur détectée : l'action doit être relancé la lentille n'est pas présente
