# %%
from science_jubilee.JubileeManager import JubileeManager
from science_jubilee.decks.LoadAll import load_all
from science_jubilee.tools.Loop import Loop

# %%
# Connexion à la Jubilee
jm = JubileeManager(address="10.0.9.6", simulated=True)
# Out:
# 2026-02-27 15:26:00 - [JubileeController]  - INFO - Initializing JubileeController (simulated=True, address=10.0.9.6)
# 2026-02-27 15:26:00 - [JubileeController]  - WARNING - Disconnecting this application from the network will halt connection to Jubilee.
# 2026-02-27 15:26:00 - [JubileeController]  - INFO - Running in simulation mode. No connection established.
# 2026-02-27 15:26:00 - [JubileeManager]     - INFO - JubileeManager initialized (simulated=True, max_tools=4).

# %%
# Homing
jm.controller.home_all()
# Out:
# Is a tool currently mounted? [y/n]  n
# Is the deck clear of any obstacles? [y/n]  y

# %%
# Descendre le plateau pour positionner le deck
jm.controller.move_to(z=300)
jm.controller.move_to(x=150, y=150)
# Out:
# 2026-02-27 15:26:16 - [JubileeController]  - INFO - (SIMULATED) move_to(x=None, y=None, z=300, u=None, s=6000, param=None, wait=False)
# 2026-02-27 15:26:16 - [JubileeController]  - INFO - (SIMULATED) move_to(x=150, y=150, z=None, u=None, s=6000, param=None, wait=False)

# %%
# Enregistrer le deck
deck = jm.load_deck("test1")
load_all(jm,"test1")
# Out:
# 2026-02-27 15:26:17 - [Deck]               - INFO - Loading deck configuration from: D:\Polytech\2025-2026\projet_indus\science-jubilee\src\science_jubilee\decks\deck_definition\test1.json
# 2026-02-27 15:26:17 - [Deck]               - INFO - Deck 'Experience1' loaded with 2 slots.
# 2026-02-27 15:26:17 - [JubileeManager]     - INFO - Deck 'Experience1' loaded from 'D:\Polytech\2025-2026\projet_indus\science-jubilee\src\science_jubilee\decks\deck_definition'.

# %%
#affiche les slots
jm.deck.list_slots()
jm.deck.get_all_slot_machine_coordinates()
# Out:
# {'0': (13.12, 10.26), '1': (100.79, 208.93)}

# %%
jm.status()
# Out:
# {'deck': 'Experience1',
#  'tools': [],
#  'active_tool_index': None,
#  'active_tool_name': None,
#  'tool_offsets': {}}

# %%
# jm.controller.move_to(x=150, y=150)
jm.controller.move_to(z=50)
# Out:
# 2026-02-27 15:26:25 - [JubileeController]  - INFO - (SIMULATED) move_to(x=None, y=None, z=50, u=None, s=6000, param=None, wait=False)

# %%
slot = jm.deck.get_slot(0)
labware = slot.labware
#puit_scource = jm.deck.get_slot('A1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 labware = slot.labware
#       2 #puit_scource = jm.deck.get_slot('A1')
#
# NameError: name 'slot' is not defined
